# %%
import pandas as pd

# %%
df = pd.read_excel("Enrolment_2021.xlsx")

# %%
df.head()
# Out:
#         statename  state_code districtname districtcode admin_district_name  \
# 0  MADHYA PRADESH          23      KHANDWA        2329A            KHARGONE
# 1       RAJASTHAN           8      UDAIPUR         826A             UDAIPUR
# 2       RAJASTHAN           8      UDAIPUR         826A             UDAIPUR
# 3       RAJASTHAN           8     SALUMBER         826B             UDAIPUR
# 4       RAJASTHAN           8     SALUMBER         826B             UDAIPUR
#
#   admin_district_code    blockname blockcode mainblockname  mainblockcode  \
# 0                2327  BHIKAN GOAN   232708A   BHIKAN GOAN       232708.0
# 1                 826      BHINDER    82604A         MAVLI        82603.0
# 2                 826      KOTRA 2    82606B         KOTRA        82606.0
# 3                 826       SARADA    82609A    RISHABHDEV        82612.0
# 4                 826     SALUMBAR    82610A      LASADIYA        82611.0
#
# ...

# %%
# !pip install dtale
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the '/Users/aadityakamble/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import dtale

# %%
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://Aadityas-MacBook-Air.local:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
